# %% [markdown]
# # Softwaredesign B

# %% [markdown]
# ## B.1 Indent is important in Python

# %% [markdown]
# ###  Explain the outputs of the following code snippets, (compare Matthes 2023, chap. 4):

# %%
import OS

# %% [markdown]
# ## B.2 Lists, conditionals and loops

# %% [markdown]
# ### For two given lists list1 and list2 of integers with equal length define the following new lists:
